# %% [markdown]
# ---
# # **API URL FOR POST REQUEST**

# %%
import requests

# %%
url = "https://jsonplaceholder.typicode.com/posts"

# %% [markdown]
# Data to Send With Request

# %%
data = {

    'Title':'New Post',
    'Body':'This is a new post created using the request module.',
    'UserId':1
}

response = requests.post(url , json=data)

print(f"Status Code: {response.status_code} = Response Successfully!")
print('_'*100)
print(f"Response Content: {response.json()}")
print('_'*100)
# Out:
# Status Code: 201 = Response Successfully!
# ____________________________________________________________________________________________________
# Response Content: {'Title': 'New Post', 'Body': 'This is a new post created using the request module.', 'UserId': 1, 'id': 101}
# ____________________________________________________________________________________________________

# %%
if response.status_code >= 200:

    print("Response Successfully!")
    print('_'*20)

else:

    print(f"Error {response.status_code} unable to fetch data.")
# Out:
# Response Successfully!
# ____________________
